# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("best_books_ever_cleaned_v02.xlsx")
df.head(5)
# Out:
#                                        book_id  \
# 0                     2767052-the-hunger-games
# 1  2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                   2657.To_Kill_a_Mockingbird
# 3                               41865.Twilight
# 4                         19063.The_Book_Thief
#
#                                        title                 series  \
# 0                           The Hunger Games    The Hunger Games #1
# 1  Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                      To Kill a Mockingbird  To Kill a Mockingbird
# 3                                   Twilight   The Twilight Saga #1
# 4                             The Book Thief                    NaN
#
#                                        author  rating  \
# 0                             Suzanne Collins    4.33
# 1  J.K. Rowling, Mary GrandPrÃ© (Illustrator)    4.50
# 2                                  Harper Lee    4.28
# 3                             Stephenie Meyer    3.60
# 4             Markus Zusak (Goodreads Author)    4.37
#
#                                          description language            isbn  \
# 0  WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...  English   9780000000000
# 1  There is a door at the end of a silent corrido...  English   9780000000000
# 2  The unforgettable novel of a childhood in a sl...  English  10000000000000
# 3  About three things I was absolutely positive.\...  English   9780000000000
# 4  Librarian's note: An alternate cover edition c...  English   9780000000000
#
#                                               genres  \
# 0  ['Young Adult', 'Fiction', 'Dystopia', 'Fantas...
# 1  ['Fantasy', 'Young Adult', 'Fiction', 'Magic',...
# 2  ['Classics', 'Fiction', 'Historical Fiction', ...
# 3  ['Young Adult', 'Fantasy', 'Romance', 'Vampire...
# 4  ['Historical Fiction', 'Fiction', 'Young Adult...
#
#                                           characters  ...  \
# 0  ['Katniss Everdeen', 'Peeta Mellark', 'Cato (H...  ...
# 1  ['Sirius Black', 'Draco Malfoy', 'Ron Weasley'...  ...
# 2  ['Scout Finch', 'Atticus Finch', 'Jem Finch', ...  ...
# 3  ['Edward Cullen', 'Jacob Black', 'Laurent', 'R...  ...
# 4  ['Liesel Meminger', 'Hans Hubermann', 'Rudy St...  ...
#
#                        award34                                   award35  \
# 0   'Prix Et-lisez-moi (2011)'   'Missouri Gateway Readers Award (2011)'
# 1                          NaN                                       NaN
# 2                          NaN                                       NaN
# 3                          NaN                                       NaN
# 4                          NaN                                       NaN
#
#                                              award36  \
# 0   'Oklahoma Sequoyah Award for High School and ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                              award37  \
# 0   'Premio El Templo de las Mil Puertas for Mejo...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                              award38  \
# 0   "Rebecca Caudill Young Readers' Book Award (2...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                         award39  \
# 0   'LovelyBooks Leserpreis for Fantasy (2009)'
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#                                              award40  \
# 0   'LovelyBooks Leserpreis for Bestes Cover/Umsc...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                              award41  \
# 0   'Premi Protagonista Jove for Categoria 13-14 ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    consolidated_book_format consolidated_publisher
# 0                 Hardcover             Scholastic
# 1                 Paperback             Scholastic
# 2                 Paperback          HarperCollins
# 3                 Paperback    Hachette Book Group
# 4                 Hardcover   Penguin Random House
#
# [5 rows x 70 columns]

# %%
columns_to_exclude = ["book_id", "description", "language", "isbn", "genres", "characters", "book_format", "edition", "pages", "number_of_ratings", "ratings_by_stars", "liked_percent", "setting", "cover_image", "bbe_score", "bbe_votes", "price","awards"]
df = df[df.columns.difference(columns_to_exclude)]
date_columns = ["first_publish_date", "publish_date"]
for column in date_columns:
    df[column] = pd.to_datetime(df[column], errors = "coerce")

df.head(5)
# Out:
#                                        author  \
# 0                             Suzanne Collins
# 1  J.K. Rowling, Mary GrandPrÃ© (Illustrator)
# 2                                  Harper Lee
# 3                             Stephenie Meyer
# 4             Markus Zusak (Goodreads Author)
#
#                                               award1  \
# 0  'Locus Award Nominee for Best Young Adult Book...
# 1  'Bram Stoker Award for Works for Young Readers...
# 2                'Pulitzer Prize for Fiction (1961)'
# 3                  'Georgia Peach Book Award (2007)'
# 4  'National Jewish Book Award for Childrenâ€™s a...
#
#                                              award10  \
# 0                           'Charlotte Award (2010)'
# 1                                                NaN
# 2                                                NaN
# 3   'Maryland Black-Eyed Susan Book Award for Hig...
# 4                             'Zilveren Zoen (2008)'
#
#                                              award11  \
# 0   'Colorado Blue Spruce Young Adult Book Award ...
# 1                                                NaN
# 2                                                NaN
# 3        'Golden Sower Award for Young Adult (2009)'
# 4   'Teen Read Award Nominee for Best All-Time-Fa...
#
#                                              award12  \
# 0                   'Teen Buckeye Book Award (2009)'
# 1                                                NaN
# 2                                                NaN
# 3   "Nevada Young Readers' Award for Young Adult ...
# 4   'Deutscher Jugendliteraturpreis for Preis der...
#
#                                              award13  \
# 0   "Pennsylvania Young Readers' Choice Award for...
# 1                                                NaN
# 2                                                NaN
# 3   "The Flume: New Hampshire Teen Reader's Choic...
# 4   'Association of Jewish Libraries for Teen Boo...
#
#                                              award14  \
# 0              'Rhode Island Teen Book Award (2010)'
# 1                                                NaN
# 2                                                NaN
# 3   "Pennsylvania Young Readers' Choice Award for...
# 4                     'Lincoln Award Nominee (2010)'
#
#                                              award15  \
# 0   "Dorothy Canfield Fisher Children's Book Awar...
# 1                                                NaN
# 2                                                NaN
# 3              'Rhode Island Teen Book Award (2007)'
# 4   'Australian Book Industry Award (ABIA) Nomine...
#
#                                award16  \
# 0   'Evergreen Teen Book Award (2011)'
# 1                                  NaN
# 2                                  NaN
# 3   'Evergreen Teen Book Award (2008)'
# 4            'Kathleen Mitchell Award'
#
#                                              award17  ...  \
# 0                  'Soaring Eagle Book Award (2009)'  ...
# 1                                                NaN  ...
# 2                                                NaN  ...
# 3   'Michigan Library Association Thumbs Up! Awar...  ...
# 4                            'Ena Noel Award (2008)'  ...
#
#                                   awards_bracketless consolidated_book_format  \
# 0  'Locus Award Nominee for Best Young Adult Book...                Hardcover
# 1  'Bram Stoker Award for Works for Young Readers...                Paperback
# 2  'Pulitzer Prize for Fiction (1961)', 'Audie Aw...                Paperback
# 3  'Georgia Peach Book Award (2007)', 'Buxtehuder...                Paperback
# 4  'National Jewish Book Award for Childrenâ€™s a...                Hardcover
#
#   consolidated_publisher first_publish_date number_of_awards publish_date  \
# 0             Scholastic                NaT               41   2008-09-14
# 1             Scholastic         2003-06-21                9   2004-09-28
# 2          HarperCollins         1960-07-11                4   2006-05-23
# 3    Hachette Book Group         2005-10-05               25   2006-09-06
# 4   Penguin Random House         2005-09-01               20   2006-03-14
#
#                           publisher rating                 series  \
# 0                  Scholastic Press   4.33    The Hunger Games #1
# 1                   Scholastic Inc.   4.50        Harry Potter #5
# 2  Harper Perennial Modern Classics   4.28  To Kill a Mockingbird
# 3         Little, Brown and Company   3.60   The Twilight Saga #1
# 4                   Alfred A. Knopf   4.37                    NaN
#
#                                        title
# 0                           The Hunger Games
# 1  Harry Potter and the Order of the Phoenix
# 2                      To Kill a Mockingbird
# 3                                   Twilight
# 4                             The Book Thief
#
# [5 rows x 52 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import altair as alt

# %%
total_publishers = len(df["publisher"].unique())
print(total_publishers)
# Out:
# 2476

# %% [markdown]
# ### In total, there are 2476 distinct publishing houses who have published award winning books. However, for the purposes of this project, we will only focus on the top 20 publishing houses shown below.

# %%
total_awards_per_house = df.groupby("publisher")["number_of_awards"].sum()
total_awards_per_house = total_awards_per_house.sort_values(ascending=False)
total_awards_per_house.head(20)
# Out:
# publisher
# Vintage                                  511
# HarperCollins                            359
# Little, Brown Books for Young Readers    338
# Scholastic Press                         287
# Random House                             267
# Tor Books                                266
# Penguin Books                            257
# Knopf                                    254
# Little, Brown and Company                238
# Del Rey                                  207
# Orbit                                    203
# Scribner                                 200
# Ballantine Books                         198
# Puffin Books                             193
# Alfred A. Knopf                          181
# Harper Perennial                         158
# Candlewick Press                         157
# Riverhead Books                          155
# Delacorte Press                          153
# Harper                                   142
# Name: number_of_awards, dtype: int64

# %%
chart = alt.Chart(total_awards_per_house.head(20).reset_index()).mark_bar(color="teal").encode(
    x=alt.X('publisher:N', title='Publisher', sort=alt.EncodingSortField(field='number_of_awards', order='descending')),
    y=alt.Y('number_of_awards:Q', title='Total Number of Awards'),
    tooltip=['publisher:N', 'number_of_awards:Q']
).properties(
    width=600,
    title='Top 20 Publishers by Total Number of Awards'
)

chart
# Out:
# alt.Chart(...)

# %%
top_4 = total_awards_per_house.head(4).index.tolist()

df_houses = df[df["publisher"].isin(top_4)]
df_houses.head(5)
# Out:
#                                                 author  \
# 0                                      Suzanne Collins
# 44   Leo Tolstoy, Aylmer Maude (Translator), Lev To...
# 81                                         Mark Haddon
# 87                                       Truman Capote
# 121                                 Katherine Paterson
#
#                                                 award1  \
# 0    'Locus Award Nominee for Best Young Adult Book...
# 44   'PEN Translation Prize for Richard Pevear & La...
# 81          'Booker Prize Nominee for Longlist (2003)'
# 87            'Edgar Award for Best Fact Crime (1966)'
# 121                             'Newbery Medal (1978)'
#
#                              award10  \
# 0           'Charlotte Award (2010)'
# 44                               NaN
# 81    'Lincoln Award Nominee (2006)'
# 87                               NaN
# 121                              NaN
#
#                                                award11  \
# 0     'Colorado Blue Spruce Young Adult Book Award ...
# 44                                                 NaN
# 81    "Commonwealth Writers' Prize for Best First B...
# 87                                                 NaN
# 121                                                NaN
#
#                                              award12  \
# 0                   'Teen Buckeye Book Award (2009)'
# 44                                               NaN
# 81    'North East Teenage Book Award Nominee (2004)'
# 87                                               NaN
# 121                                              NaN
#
#                                                award13  \
# 0     "Pennsylvania Young Readers' Choice Award for...
# 44                                                 NaN
# 81                     'Carnegie Medal Nominee (2003)'
# 87                                                 NaN
# 121                                                NaN
#
#                                               award14  \
# 0               'Rhode Island Teen Book Award (2010)'
# 44                                                NaN
# 81    "Dolly Gray Children's Literature Award (2004)"
# 87                                                NaN
# 121                                               NaN
#
#                                                award15  \
# 0     "Dorothy Canfield Fisher Children's Book Awar...
# 44                                                 NaN
# 81    'Premi Protagonista Jove for Categoria 15-16 ...
# 87                                                 NaN
# 121                                                NaN
#
#                                  award16                             award17  \
# 0     'Evergreen Teen Book Award (2011)'   'Soaring Eagle Book Award (2009)'
# 44                                   NaN                                 NaN
# 81                                   NaN                                 NaN
# 87                                   NaN                                 NaN
# 121                                  NaN                                 NaN
#
#      ...                                 awards_bracketless  \
# 0    ...  'Locus Award Nominee for Best Young Adult Book...
# 44   ...  'PEN Translation Prize for Richard Pevear & La...
# 81   ...  'Booker Prize Nominee for Longlist (2003)', 'J...
# 87   ...           'Edgar Award for Best Fact Crime (1966)'
# 121  ...  'Newbery Medal (1978)', 'Lewis Carroll Shelf A...
#
#     consolidated_book_format consolidated_publisher first_publish_date  \
# 0                  Hardcover             Scholastic                NaT
# 44                 Paperback   Penguin Random House         1977-10-28
# 81                 Paperback   Penguin Random House         2003-07-31
# 87                 Paperback   Penguin Random House         1965-10-28
# 121                    Ebook          HarperCollins         1977-10-21
#
#     number_of_awards publish_date         publisher rating  \
# 0                 41   2008-09-14  Scholastic Press   4.33
# 44                 1   2012-10-16           Vintage   4.05
# 81                15   2004-05-18           Vintage   3.88
# 87                 1   1994-10-28           Vintage   4.07
# 121                5   2009-10-06     HarperCollins   4.01
#
#                   series                                              title
# 0    The Hunger Games #1                                   The Hunger Games
# 44                   NaN                                      Anna Karenina
# 81                   NaN  The Curious Incident of the Dog in the Night-Time
# 87                   NaN                                      In Cold Blood
# 121                  NaN                               Bridge to Terabithia
#
# [5 rows x 52 columns]

# %%
brush = alt.selection_interval()

points = alt.Chart(df_houses).mark_point().encode(
    x='rating:Q',
    y='number_of_awards:Q',
    color='publisher:N',
    tooltip=['title:N', 'rating:Q', 'number_of_awards:Q']
).add_selection(
    brush
)

bars = alt.Chart(df_houses).mark_bar().encode(
    x='count()',
    y='publisher:N',
    color='publisher:N'
).transform_filter(
    brush
)

points & bars
# Out:
# C:\Users\sally\anaconda3\lib\site-packages\altair\utils\deprecation.py:65: AltairDeprecationWarning: 'add_selection' is deprecated. Use 'add_params' instead.
#   warnings.warn(message, AltairDeprecationWarning, stacklevel=1)
# alt.VConcatChart(...)
